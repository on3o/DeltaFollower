# %%
from acquire import stock

stock.OneDailyData().save2csv("../data_store/")
# Out:
# 股票：000001.SZ已存入到../data_store/daily/price/000001.SZ.csv
# 股票：000001.SZ已存入到../data_store/daily/basic/000001.SZ.csv
# 000001.SZ已存入
# 股票：000002.SZ已存入到../data_store/daily/price/000002.SZ.csv
# 股票：000002.SZ已存入到../data_store/daily/basic/000002.SZ.csv
# 000002.SZ已存入
# 股票：000004.SZ已存入到../data_store/daily/price/000004.SZ.csv
# 股票：000004.SZ已存入到../data_store/daily/basic/000004.SZ.csv
# 000004.SZ已存入
# 股票：000005.SZ已存入到../data_store/daily/price/000005.SZ.csv
# 股票：000005.SZ已存入到../data_store/daily/basic/000005.SZ.csv
# 000005.SZ已存入
# 股票：000006.SZ已存入到../data_store/daily/price/000006.SZ.csv
# 股票：000006.SZ已存入到../data_store/daily/basic/000006.SZ.csv
# 000006.SZ已存入
# 股票：000007.SZ已存入到../data_store/daily/price/000007.SZ.csv
# 股票：000007.SZ已存入到../data_store/daily/basic/000007.SZ.csv
# 000007.SZ已存入
# 股票：000008.SZ已存入到../data_store/daily/price/000008.SZ.csv
# 股票：000008.SZ已存入到../data_store/daily/basic/000008.SZ.csv
# 000008.SZ已存入
# 股票：000009.SZ已存入到../data_store/daily/price/000009.SZ.csv
# ...
